# %%
#import python libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#read data set

# %%
cars=pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Data Science\Python Data Trials\car data.csv')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
cars.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
cars.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
cars.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
sns.jointplot(x='Selling_Price', y='Present_Price', data=cars,kind='scatter',hue='Fuel_Type')

# %%
sns.barplot(x='Car_Name',y='Selling_Price',hue='Transmission', data=cars)
# Out:
# <AxesSubplot:xlabel='Car_Name', ylabel='Selling_Price'>

# %%
cars['Selling_Price'].max()
# Out:
# 35.0

# %%
cars.loc[(cars['Selling_Price'].max())]
# Out:
# Car_Name            sx4
# Year               2011
# Selling_Price      2.95
# Present_Price      7.74
# Driven_kms        49998
# Fuel_Type           CNG
# Selling_type     Dealer
# Transmission     Manual
# Owner                 0
# Name: 35, dtype: object

# %%
cars['Present_Price'].max()
# Out:
# 92.6

# %%
cars.loc[(cars['Present_Price']>=92.6)]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Selling_type Transmission  Owner
# 86       Dealer       Manual      0

# %%
cars['Driven_kms'].max()
# Out:
# 500000

# %%
cars.loc[(cars['Driven_kms']>=500000)]
# Out:
#       Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 196  Activa 3g  2008           0.17           0.52      500000    Petrol
#
#     Selling_type Transmission  Owner
# 196   Individual    Automatic      0

# %%
sns.pairplot(data=cars, hue='Transmission')

# %%
cars.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    148
# Driven_kms       206
# Fuel_Type          3
# Selling_type       2
# Transmission       2
# Owner              3
# dtype: int64

# %%
AorM = pd.get_dummies(cars['Transmission'], drop_first=True)

# %%
AorM
# Out:
#      Manual
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 296       1
# 297       1
# 298       1
# 299       1
# 300       1
#
# [301 rows x 1 columns]

# %%
cars2 = pd.concat([cars, AorM], axis=1)

# %%
cars2
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Manual
# 0         Dealer       Manual      0       1
# ...

# %%
theseller= pd.get_dummies(cars['Selling_type'], drop_first=True)

# %%
theseller
# Out:
#      Individual
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 296           0
# 297           0
# 298           0
# 299           0
# 300           0
#
# [301 rows x 1 columns]

# %%
cars3 = pd.concat([cars2, theseller], axis=1)

# %%
cars3
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Manual  Individual
# 0         Dealer       Manual      0       1           0
# ...

# %%
final=cars3.drop(cars3[['Car_Name','Fuel_Type','Selling_type','Transmission']], axis=1)

# %%
final.head(5)
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms  Owner  Manual  Individual
# 0  2014           3.35           5.59       27000      0       1           0
# 1  2013           4.75           9.54       43000      0       1           0
# 2  2017           7.25           9.85        6900      0       1           0
# 3  2011           2.85           4.15        5200      0       1           0
# 4  2014           4.60           6.87       42450      0       1           0

# %%
#Training Data

# %%
from sklearn.model_selection import train_test_split

# %%
X = final.drop('Selling_Price', axis=1).values

# %%
y = final['Selling_Price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[2.0150e+03, 1.0790e+01, 4.1678e+04, 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [2.0090e+03, 1.7500e+00, 4.0000e+04, 0.0000e+00, 1.0000e+00,
#         1.0000e+00],
#        [2.0150e+03, 7.5000e+00, 4.4000e+04, 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        ...,
#        [2.0140e+03, 3.4500e+00, 1.6500e+04, 1.0000e+00, 1.0000e+00,
#         1.0000e+00],
#        [2.0110e+03, 1.0000e+01, 6.9341e+04, 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [2.0170e+03, 1.7800e+00, 4.0000e+03, 0.0000e+00, 1.0000e+00,
#         1.0000e+00]])

# %%
X_test
# Out:
# array([[2.01600e+03, 5.70000e-01, 2.40000e+04, 0.00000e+00, 0.00000e+00,
#         1.00000e+00],
#        [2.01600e+03, 1.36000e+01, 1.09800e+04, 0.00000e+00, 1.00000e+00,
#         0.00000e+00],
#        [2.01200e+03, 9.40000e+00, 6.00000e+04, 0.00000e+00, 1.00000e+00,
#         0.00000e+00],
#        [2.01100e+03, 5.70000e-01, 3.50000e+04, 1.00000e+00, 1.00000e+00,
#         1.00000e+00],
#        [2.01300e+03, 1.86100e+01, 4.00010e+04, 0.00000e+00, 1.00000e+00,
#         0.00000e+00],
#        [2.01500e+03, 8.92000e+00, 4.23670e+04, 0.00000e+00, 1.00000e+00,
#         0.00000e+00],
#        [2.01500e+03, 1.47000e+00, 2.60000e+04, 0.00000e+00, 1.00000e+00,
#         1.00000e+00],
#        [2.01400e+03, 8.80000e-01, 8.00000e+03, 0.00000e+00, 1.00000e+00,
#         1.00000e+00],
#        [2.01600e+03, 5.40000e-01, 1.40000e+04, 0.00000e+00, 1.00000e+00,
#         1.00000e+00],
#        [2.01400e+03, 9.95000e+00, 4.50000e+04, 0.00000e+00, 1.00000e+00,
#         0.00000e+00],
# ...

# %%
#Normalize data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 9.28571429e-01,  1.08542277e-03,  1.10588235e-01,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 9.28571429e-01,  1.42516010e-01,  4.93176471e-02,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 6.42857143e-01,  9.69282536e-02,  2.80000000e-01,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 5.71428571e-01,  1.08542277e-03,  1.62352941e-01,
#          3.33333333e-01,  1.00000000e+00,  1.00000000e+00],
#        [ 7.14285714e-01,  1.96895691e-01,  1.85887059e-01,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 8.57142857e-01,  9.17182242e-02,  1.97021176e-01,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 8.57142857e-01,  1.08542277e-02,  1.20000000e-01,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 7.85714286e-01,  4.45023337e-03,  3.52941176e-02,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
# ...

# %%
#Creating Model

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (201, 6)

# %%
model = Sequential()

# %%
model.add(Dense(6, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(6, activation='relu'))

model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mse')

# %%
#Fitting model

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 2/2 [==============================] - 1s 305ms/step - loss: 43.1845 - val_loss: 45.8296
# Epoch 2/400
# 2/2 [==============================] - 0s 48ms/step - loss: 42.9807 - val_loss: 45.6206
# Epoch 3/400
# 2/2 [==============================] - 0s 48ms/step - loss: 42.7692 - val_loss: 45.4095
# Epoch 4/400
# 2/2 [==============================] - 0s 42ms/step - loss: 42.5515 - val_loss: 45.1966
# Epoch 5/400
# 2/2 [==============================] - 0s 43ms/step - loss: 42.3404 - val_loss: 44.9813
# Epoch 6/400
# 2/2 [==============================] - 0s 65ms/step - loss: 42.1201 - val_loss: 44.7647
# Epoch 7/400
# 2/2 [==============================] - 0s 48ms/step - loss: 41.9068 - val_loss: 44.5459
# Epoch 8/400
# 2/2 [==============================] - 0s 43ms/step - loss: 41.6916 - val_loss: 44.3272
# Epoch 9/400
# 2/2 [==============================] - 0s 66ms/step - loss: 41.4544 - val_loss: 44.1107
# Epoch 10/400
# ...

# %%
#Model Evaluation

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 5.874324321746826

# %%
model.evaluate(X_train, y_train, verbose=0)
# Out:
# 5.936276435852051

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
print(predictions)
# Out:
# [[ 1.4927577 ]
#  [ 7.945668  ]
#  [ 5.651391  ]
#  [ 0.2116175 ]
#  [ 8.164821  ]
#  [ 6.6195083 ]
#  [ 0.64276564]
#  [ 0.41591734]
#  [ 0.7190542 ]
#  [ 6.4866076 ]
#  [ 7.767908  ]
#  [ 0.38188633]
#  [ 9.459092  ]
#  [ 1.3827593 ]
#  [ 5.949024  ]
#  [ 4.9841704 ]
#  [ 0.1615777 ]
#  [ 9.564588  ]
#  [ 0.84217405]
#  [ 0.8438954 ]
#  [ 0.2839519 ]
#  [ 6.9786444 ]
#  [ 5.4566708 ]
#  [ 3.8889976 ]
#  [ 0.48394224]
#  [ 4.837615  ]
#  [ 6.1535454 ]
#  [ 4.226779  ]
#  [ 0.8728243 ]
#  [ 0.75655913]
#  [ 0.30067396]
#  [ 7.603079  ]
#  [-0.08496696]
#  [ 3.5396328 ]
#  [ 7.4841576 ]
#  [ 5.695263  ]
#  [ 7.42943   ]
#  [ 6.7069454 ]
#  [ 4.813016  ]
#  [ 7.008575  ]
#  [ 4.2235794 ]
#  [ 7.115693  ]
#  [ 5.4360557 ]
#  [ 0.5452928 ]
#  [ 6.480862  ]
#  [ 0.3718199 ]
#  [ 7.3443947 ]
#  [10.940863  ]
#  [ 4.6703544 ]
#  [ 4.9581423 ]
#  [ 8.559835  ]
#  [ 0.84624195]
#  [15.920164  ]
#  [13.9313755 ]
#  [ 6.870589  ]
#  [10.75751   ]
#  [ 5.566067  ]
#  [ 7.618724  ]
# ...

# %%
predictions=pd.Series(predictions.reshape(100,))

# %%
pred_df = pd.DataFrame(y_test, columns=['Test True Y'])

# %%
pred_df
# Out:
#     Test True Y
# 0          0.35
# 1         10.11
# 2          4.95
# 3          0.15
# 4          6.95
# ..          ...
# 95         0.17
# 96         3.35
# 97         4.35
# 98         5.25
# 99         0.35
#
# [100 rows x 1 columns]

# %%
pred_df = pd.concat([pred_df, predictions], axis=1)

# %%
pred_df.columns =['Test True Y', 'Model Predictions']

# %%
pred_df
# Out:
#     Test True Y  Model Predictions
# 0          0.35           1.492758
# 1         10.11           7.945668
# 2          4.95           5.651391
# 3          0.15           0.211617
# 4          6.95           8.164821
# ..          ...                ...
# 95         0.17           6.836410
# 96         3.35           5.033524
# 97         4.35           6.505932
# 98         5.25           5.708079
# 99         0.35          -0.091338
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(x='Test True Y', y='Model Predictions', data = pred_df)
# Out:
# <AxesSubplot:xlabel='Test True Y', ylabel='Model Predictions'>

# %%
#Evaluation of Regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 1.5285578117728233

# %%
final.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner  \
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000
#
#            Manual  Individual
# count  301.000000  301.000000
# mean     0.867110    0.352159
# std      0.340021    0.478439
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
mean_squared_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 5.874324615769078

# %%
Root_mean_squared_error = (mean_squared_error(pred_df['Test True Y'], pred_df['Model Predictions']))**0.5

# %%
Root_mean_squared_error
# Out:
# 2.423700603574847

# %%
#making a prediction

# %%
#Comparing the Final table
final.head(5)
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms  Owner  Manual  Individual
# 0  2014           3.35           5.59       27000      0       1           0
# 1  2013           4.75           9.54       43000      0       1           0
# 2  2017           7.25           9.85        6900      0       1           0
# 3  2011           2.85           4.15        5200      0       1           0
# 4  2014           4.60           6.87       42450      0       1           0

# %%
#I'm going to use the [0] row as a trail and drop the 'Selling_Price' column
single_car= final.drop('Selling_Price', axis=1).iloc[0]

# %%
single_car
# Out:
# Year              2014.00
# Present_Price        5.59
# Driven_kms       27000.00
# Owner                0.00
# Manual               1.00
# Individual           0.00
# Name: 0, dtype: float64

# %%
single_car = scaler.transform(single_car.values.reshape(-1,6))

# %%
model.predict(single_car)
# Out:
# 1/1 [==============================] - 0s 73ms/step
# array([[5.2943697]], dtype=float32)
